# %% [markdown]
# <a href="https://colab.research.google.com/github/chirusainanda/Data-Cleaning/blob/main/Copy_of_Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c36ab09e-bcfd-400d-a621-0929148daadf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c36ab09e-bcfd-400d-a621-0929148daadf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Replace with the uploaded file name if different
df = pd.read_csv("Automobile_data.csv")

# Check it worked
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'horsepower' to numeric (handle missing values)
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')

# Plot the distribution
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.histplot(df['horsepower'].dropna(), kde=True, bins=20, color='dodgerblue')
plt.title('Distribution of Horsepower')
plt.xlabel('Horsepower')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Define the README.md content
readme_content = """# Task 1: Data Cleaning and Preprocessing

## ✅ Objective
Clean a raw automobile dataset by handling missing values, fixing data types, removing duplicates, and visualizing key features.

## 🛠 Tools Used
- Python
- Pandas
- Matplotlib
- Seaborn
- Jupyter Notebook / Google Colab

## 📌 Key Steps
- Converted object-type numeric columns (e.g., horsepower, price) to numeric
- Filled or removed missing values
- Standardized column names
- Plotted histogram of 'horsepower'
- Saved the cleaned dataset

## 📊 Output
![Horsepower Distribution](plots/horsepower_plot.png)

## 📁 Files
- `Automobile_data.csv`: Raw data
- `cleaning_script.py`: Python code used
- `cleaned_dataset.csv`: Final cleaned dataset
- `README.md`: This file

## 🔗 Submission
Submitted as part of the Data Analyst Internship Task 1."""

# Save to README.md
with open("README.md", "w") as f:
    f.write(readme_content)

print("README.md has been created successfully!")
# Out:
# README.md has been created successfully!
